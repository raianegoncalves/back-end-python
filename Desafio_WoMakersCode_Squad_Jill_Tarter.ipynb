# %% [markdown]
# <a href="https://colab.research.google.com/github/raianegoncalves/back-end-python/blob/main/Desafio_WoMakersCode_Squad_Jill_Tarter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Instalação das bibliotecas pydataset, pandas e numpy

# %%
# !pip install pydataset
# !pip install pandas

# %% [markdown]
# #Importação das bibliotecas pydataset, pandas e numpy

# %%
from pydataset import data
import pandas as pd

# %% [markdown]
# #Importação do dataset "Bundesliga" do pydataset

# %%
df = data('Bundesliga')
df.head()
# Out:
#               HomeTeam              AwayTeam  HomeGoals  AwayGoals  Round  Year  \
# 1        Werder Bremen     Borussia Dortmund          3          2      1  1963
# 2    Hertha BSC Berlin       1. FC Nuernberg          1          1      1  1963
# 3    Preussen Muenster          Hamburger SV          1          1      1  1963
# 4  Eintracht Frankfurt  1. FC Kaiserslautern          1          1      1  1963
# 5        Karlsruher SC        Meidericher SV          1          4      1  1963
#
#                   Date
# 1  1963-08-24 09:30:00
# 2  1963-08-24 09:30:00
# 3  1963-08-24 09:30:00
# 4  1963-08-24 09:30:00
# 5  1963-08-24 09:30:00

# %% [markdown]
# **DESAFIO**
#
# **1. Verificar os jogos com maior quantidade de gols na história da
# Bundesliga**
#
# **2. Informar a data, os times participantes e o placar do jogo**
#
# **Dicas:
# Criar uma nova variável "TotalGoals" com o total de gols da
# partida;
# Use o método.max()**

# %% [markdown]
# #Explorando o dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14018 entries, 1 to 14018
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   HomeTeam   14018 non-null  object
#  1   AwayTeam   14018 non-null  object
#  2   HomeGoals  14018 non-null  int64
#  3   AwayGoals  14018 non-null  int64
#  4   Round      14018 non-null  int64
#  5   Year       14018 non-null  int64
#  6   Date       14016 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#           HomeGoals     AwayGoals         Round          Year
# count  14018.000000  14018.000000  14018.000000  14018.000000
# mean       1.898131      1.190755     17.485733   1985.736196
# std        1.468427      1.154163      9.819479     13.135278
# min        0.000000      0.000000      1.000000   1963.000000
# 25%        1.000000      0.000000      9.000000   1974.000000
# 50%        2.000000      1.000000     17.000000   1986.000000
# 75%        3.000000      2.000000     26.000000   1997.000000
# max       12.000000      9.000000     38.000000   2008.000000

# %% [markdown]
# #Criando a coluna TotalGoals a partir da soma das colunas HomeGoals e AwayGoals

# %%
df['TotalGoals'] = df['HomeGoals'] + df['AwayGoals']
df
# Out:
#                         HomeTeam              AwayTeam  HomeGoals  AwayGoals  Round  Year  \
# 1                  Werder Bremen     Borussia Dortmund          3          2      1  1963
# 2              Hertha BSC Berlin       1. FC Nuernberg          1          1      1  1963
# 3              Preussen Muenster          Hamburger SV          1          1      1  1963
# 4            Eintracht Frankfurt  1. FC Kaiserslautern          1          1      1  1963
# 5                  Karlsruher SC        Meidericher SV          1          4      1  1963
# ...                          ...                   ...        ...        ...    ...   ...
# 14014          Arminia Bielefeld           Hannover 96          2          2     34  2008
# 14015              Karlsruher SC     Hertha BSC Berlin          4          0     34  2008
# 14016                1. FC Koeln            VfL Bochum          1          1     34  2008
# ...

# %% [markdown]
# #Encontrando o valor máximo na coluna TotalGoals

# %%
df['TotalGoals'].max()
# Out:
# 12

# %% [markdown]
# #Localizando o índice em que o valor máximo encontrado está

# %% [markdown]
# https://developersbrasil.quora.com/https-pt-quora-com-Como-encontrar-o-%C3%ADndice-da-linha-de-um-pandas-DataFrame-em-que-se-encontra-um-determinado-valor-de#:~:text=Para%20encontrar%20o%20%C3%ADndice%20da,index.

# %%
indice = df.loc[df['TotalGoals'] == 12].index[0]
indice
# Out:
# 81

# %% [markdown]
# #Printando a linha do índice encontrado

# %%
linha = df.loc[81]
linha
# Out:
# HomeTeam         Borussia Dortmund
# AwayTeam      1. FC Kaiserslautern
# HomeGoals                        9
# AwayGoals                        3
# Round                           11
# Year                          1963
# Date           1963-11-16 09:30:00
# TotalGoals                      12
# Name: 81, dtype: object

# %% [markdown]
# #O jogo com maior número de gols:
#
#
# *   **Data:** 16/11/1963
# *   **Time mandante:** Borussia Dortmund
# *   **Time visitante:** FC Kaiserslautern
# *   **Placar:** Borussia Dortmund  **9 x 3**  FC Kaiserslautern
